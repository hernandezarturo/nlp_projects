# %% [markdown]
# ### TALLER 9 - NUBE DE PALABRAS WORDCLOUD
#
# Se utiliza base de datos de quejas presentadas en un proceso de servicio al cliente, generando una nueb de palabras de las observaciones por queja radicadas por cliente

# %%
import pandas as pd
 
data = pd.read_excel('C:/Python/NLP/nlp_projects/Clase_seis/Reporte_excel_quejas.xlsx', encoding = 'UTF-8')
data.head()
# Out:
#    Número del caso   Tipo             Proceso  \
# 0   20092220249547  QUEJA    ASESORIA Y VENTA
# 1   20091720203098  QUEJA    ASESORIA Y VENTA
# 2   20092320266637  QUEJA  RECLAMACIONES VIDA
# 3   20091620193646  QUEJA          EXPEDICION
# 4   20091520183982  QUEJA          EXPEDICION
#
#                                      Causa           Filtro 2  \
# 0           INADECUADA ATENCION DEL ASESOR  VANTI-GAS NATURAL
# 1           INADECUADA ATENCION DEL ASESOR             EMCALI
# 2              DEMORA ATENCION RECLAMACION          FALABELLA
# 3  COBRO A CLIENTE QUE CANCELO EL PRODUCTO        CHEC NUEVOS
# 4                 DEMORA EN LA CANCELACION        CHEC NUEVOS
#
#                                          Descripción
# 0  SE COMUNICA EL SEÑOR JORGE INDICANDO QUE EL JA...
# 1  QUIEN MANIFIESTA INCONFORMIDAD POR QUE EN LA F...
# 2  SE COMUNICA USUARIO INFORMANDO QUE HACE MAS DE...
# 3  SE COMUNICA INDICANDO QUE SE LE SIGUE GENERAND...
# ...

# %%
import numpy as np


from wordcloud import WordCloud
from wordcloud import ImageColorGenerator

# %%
from nltk.corpus import stopwords
stopwords = stopwords.words('spanish')

import matplotlib.pyplot as plt
import PIL.Image
from IPython.display import display

# %%
palabras = data.Descripción.str.cat(sep=' ')

wordcloud = WordCloud(width=800, height=400,
                     max_font_size=150, max_words=300,
                     background_color='white', colormap='cividis',
                     stopwords=stopwords).generate(palabras) # https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html

 

plt.figure(figsize=(10,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
queja = PIL.Image.open("C:/Python/NLP/nlp_projects/queja.png")
display(queja)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=706x629 at 0x276DE0D5608>

# %%
queja_array = np.array(queja)
queja_array
# Out:
# array([[[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
# ...

# %%
# Más en https://www.datacamp.com/community/tutorials/wordcloud-python
palabras = data.Descripción.str.cat(sep=' ')

wordcloud = WordCloud(width=800, height=400,
                     max_font_size=150, max_words=250,
                     background_color='white', colormap='magma',
                     stopwords=stopwords,
                     mask=queja_array, contour_width=0.5, contour_color='black').generate(palabras) # https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html


wordcloud.to_file("C:/Python/NLP/nlp_projects/quejas_wordcloud.png")


plt.figure(figsize=(10,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()
